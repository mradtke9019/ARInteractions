# %%
import numpy as np
import pandas as pd
import math
import sys
import copy
import glob
import os
from PlotUtility import *
from DataUtility import *

# %%
title = "Gesture Execution Success Rate. 20 Trials per gesture sequence"
yLabel = "Success Rate"
xLabel = "Sequence Count"
# In order of Lighter, Fireball, Webshot, Lightning Strike, Laser Beam, Finger Gun

sequenceCount = [2,2,2,4,4,3,5,6]
successRateWithWildcard = [1, 0.95, 1, 0.7, 0.75, 1,.9,.9]
successRateNoWildcard = [.7, .8, 1, 0, .55, .15,0,.35]

WildData = ScatterData(sequenceCount,successRateWithWildcard,"green","With Wildcard", "o", .75)
NoWildData = ScatterData(sequenceCount,successRateNoWildcard,"red","No Wildcard", "x", .75)

# %%
PlotHelper(title, xLabel, yLabel, scatterData = [WildData, NoWildData], plotData = None, histogramData = None, OrderByX = True)
